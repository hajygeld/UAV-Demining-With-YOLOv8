# %%
# Install Roboflow and YOLOv8

# !pip uninstall ultralytics -y
# !pip install ultralytics

from IPython import display
display.clear_output() # Clear output from the pip install to remove clutter.

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/166.8 GB disk)

# %%
# Imports:

import os
from ultralytics import YOLO # Import the YOLO model
from IPython.display import display, Image

# %%
#!mkdir content/datasets # Make a "datasets" directory from the home directory
# and store the dataset within that directory.
# %cd /content/datasets

# !pip install roboflow --quiet # Install Roboflow base with little verbosity.

from roboflow import Roboflow

# Snippet to download and unzip the dataset:
rf = Roboflow(api_key="Ky24HUkfG6EnKlqDTAF2")
project = rf.workspace("uri-7bejc").project("uav-demining")
dataset = project.version(3).download("yolov8")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.200, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to UAV-Demining-3 in yolov8:: 100%|██████████| 7568/7568 [00:02<00:00, 2620.09it/s]

# %%
# %cd /content/

# !yolo task=detect mode=train model=yolov8s.pt data={'/content/datasets/UAV-Demining-2/'}data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8ee323aae76b> in <cell line: 1>()
# ----> 1 Image(filename = f'/content/images')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1221
#    1222         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# -> 1223             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#    1224         if self.embed:
#    1225             self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the '/content/images' image format

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train6/weights/best.pt conf=0.25 source={'/content/datasets/UAV-Demining-2'}/pfm_test save=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/13 /content/datasets/UAV-Demining-2/pfm_test/MicrosoftTeams-image (1).png: 800x608 2 PFM-1s, 96.9ms
# image 2/13 /content/datasets/UAV-Demining-2/pfm_test/MicrosoftTeams-image (10).png: 800x608 1 TM-62, 5.8ms
# image 3/13 /content/datasets/UAV-Demining-2/pfm_test/MicrosoftTeams-image (11).png: 800x608 2 TM-62s, 6.5ms
# image 4/13 /content/datasets/UAV-Demining-2/pfm_test/MicrosoftTeams-image (12).png: 384x800 (no detections), 57.0ms
# image 5/13 /content/datasets/UAV-Demining-2/pfm_test/MicrosoftTeams-image (13).png: 544x800 1 PFM-1, 55.5ms
# image 6/13 /content/datasets/UAV-Demining-2/pfm_test/MicrosoftTeams-image (2).png: 800x608 (no detections), 6.3ms
# image 7/13 /content/datasets/UAV-Demining-2/pfm_test/MicrosoftTeams-image (3).png: 800x608 1 TM-62, 5.6ms
# ...

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"/content/runs/detect/train9/")
# Out:
# Dependency ultralytics==8.0.134 is required but found version=8.0.200, to fix: `pip install ultralytics==8.0.134`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/uri-7bejc/uav-demining/3
# Share your model with the world at: https://universe.roboflow.com/uri-7bejc/uav-demining/model/3
